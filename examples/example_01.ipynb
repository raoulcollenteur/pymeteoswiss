# %% [markdown]
# # Example 1: Extract time series from gridded meteoswiss climate data
#
# *Raoul Collenteur, Collenteur Hydroconsult GmbH, 2026*

# %%
from pathlib import Path
import pymeteoswiss as pms

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Set the datapaths

# %%
path = Path("data/")

if not path.exists():
    raise FileNotFoundError(f"Data directory '{path}' does not exist. Please create it"
                            "and add the necessary data files.")

# %%
x , y = 2527330, 1163750
pms.read_data(path, variable="RhiresD", x=x, y=y)
# Out:
#                     0
# time
# 1961-01-01   2.152565
# 1961-01-02  14.197646
# 1961-01-03  18.314011
# 1961-01-04   2.912960
# 1961-01-05   0.000000
# ...               ...
# 1980-12-27   0.000000
# 1980-12-28   0.000000
# 1980-12-29   0.000000
# 1980-12-30   0.000000
# 1980-12-31   0.000000
#
# [7305 rows x 1 columns]
